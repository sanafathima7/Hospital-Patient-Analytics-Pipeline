# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/workspace/default/final_assignment/gold/doctor_performance`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import *
from pyspark.sql.window import Window

doctor_performance = spark.read.format("delta").load(
    "/Volumes/workspace/default/final_assignment/gold/doctor_performance"
)

# %%
doctor_performance.filter("doctor_rank <= 2") \
.write \
.format("delta") \
.mode("overwrite") \
.save("/Volumes/workspace/default/final_assignment/gold/doctor_performance")

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/workspace/default/final_assignment/gold/doctor_performance`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT *
FROM delta.`/Volumes/workspace/default/final_assignment/gold/doctor_performance`
VERSION AS OF 0
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
